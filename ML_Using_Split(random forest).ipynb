# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings


from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
warnings.filterwarnings('ignore')

le = preprocessing.LabelEncoder()

# %%
#loading the train and test dataset
train_df = pd.read_csv("KDDTrain+.txt")


test_df = pd.read_csv("KDDTest+.txt")
train_df
test_df
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   private   REJ          0          0     0
# 1             0           tcp   private   REJ          0          0     0
# 2             2           tcp  ftp_data    SF      12983          0     0
# 3             0          icmp     eco_i    SF         20          0     0
# 4             1           tcp    telnet  RSTO          0         15     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 22539         0           tcp      smtp    SF        794        333     0
# 22540         0           tcp      http    SF        317        938     0
# 22541         0           tcp      http    SF      54540       8314     0
# 22542         0           udp  domain_u    SF         42         42     0
# 22543         0           tcp    sunrpc   REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0                   0       0    0  ...                    0.04
# 1                   0       0    0  ...                    0.00
# 2                   0       0    0  ...                    0.61
# 3                   0       0    0  ...                    1.00
# 4                   0       0    0  ...                    0.31
# ...               ...     ...  ...  ...                     ...
# 22539               0       0    0  ...                    0.72
# 22540               0       0    0  ...                    1.00
# 22541               0       0    2  ...                    1.00
# 22542               0       0    0  ...                    0.99
# 22543               0       0    0  ...                    0.08
#
#        dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                        0.06                         0.00
# 1                        0.06                         0.00
# 2                        0.04                         0.61
# 3                        0.00                         1.00
# 4                        0.17                         0.03
# ...                       ...                          ...
# 22539                    0.06                         0.01
# 22540                    0.00                         0.01
# 22541                    0.00                         0.00
# 22542                    0.01                         0.00
# 22543                    0.03                         0.00
#
#        dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                             0.00                  0.00
# 1                             0.00                  0.00
# 2                             0.02                  0.00
# 3                             0.28                  0.00
# 4                             0.02                  0.00
# ...                            ...                   ...
# 22539                         0.01                  0.01
# 22540                         0.01                  0.01
# 22541                         0.00                  0.00
# 22542                         0.00                  0.00
# 22543                         0.00                  0.00
#
#        dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                           0.0                  1.00
# 1                           0.0                  1.00
# 2                           0.0                  0.00
# 3                           0.0                  0.00
# 4                           0.0                  0.83
# ...                         ...                   ...
# 22539                       0.0                  0.00
# 22540                       0.0                  0.00
# 22541                       0.0                  0.07
# 22542                       0.0                  0.00
# 22543                       0.0                  0.44
#
#        dst_host_srv_rerror_rate    class  severity_score
# 0                          1.00  neptune              21
# 1                          1.00  neptune              21
# 2                          0.00   normal              21
# 3                          0.00    saint              15
# 4                          0.71    mscan              11
# ...                         ...      ...             ...
# 22539                      0.00   normal              21
# 22540                      0.00   normal              21
# 22541                      0.07     back              15
# 22542                      0.00   normal              21
# 22543                      1.00    mscan              14
#
# [22544 rows x 43 columns]

# %%
#Drop severity score column



#assigning the numerical values to class  

label_train_df=train_df['class']


frame_train=label_train_df.replace({ 'normal' : 0, 'apache2': 1,'back':1, 'land': 1, 'neptune': 1, 
                                         'mailbomb': 1, 'pod': 1, 'processtable': 1, 'smurf': 1, 
                                         'teardrop': 1,'udpstorm': 1, 'worm': 1,'ipsweep' : 2,
                                         'mscan' : 2, 'nmap' : 2, 'portsweep' : 2,'satan' : 2,
                                         'saint' : 2, 'ftp_write': 3,'guess_passwd': 3,'imap': 3,
                                         'multihop': 3,'phf': 3,'spy': 3,'warezclient': 3, 'warezmaster': 3,
                            'sendmail': 3,'named': 3,'snmpgetattack': 3,'snmpguess': 3, 'xlock': 3,
                            'xsnoop': 3,'httptunnel': 3,'buffer_overflow': 4,'loadmodule': 4,'perl': 4,
                            'rootkit': 4,'ps': 4,'sqlattack': 4,'xterm': 4})



# train_df

frame_train

#frame_test
# Out:
# 0         0
# 1         0
# 2         1
# 3         0
# 4         0
#          ..
# 125968    1
# 125969    0
# 125970    0
# 125971    1
# 125972    0
# Name: class, Length: 125973, dtype: int64

# %%
#uptile here we loaded data, and we droped column-severity score
#assigned label for column class
#we mapped each class as key-value pair
# train_df = train_df.drop(['severity_score'],axis=1)
label_test_df=test_df['class']
frame_test=label_test_df.replace({ 'normal' : 0, 'apache2': 1,'back':1, 'land': 1, 'neptune': 1, 
                                         'mailbomb': 1, 'pod': 1, 'processtable': 1, 'smurf': 1, 
                                         'teardrop': 1,'udpstorm': 1, 'worm': 1,'ipsweep' : 2,
                                         'mscan' : 2, 'nmap' : 2, 'portsweep' : 2,'satan' : 2,
                                         'saint' : 2, 'ftp_write': 3,'guess_passwd': 3,'imap': 3,
                                         'multihop': 3,'phf': 3,'spy': 3,'warezclient': 3, 'warezmaster': 3,
                            'sendmail': 3,'named': 3,'snmpgetattack': 3,'snmpguess': 3, 'xlock': 3,
                            'xsnoop': 3,'httptunnel': 3,'buffer_overflow': 4,'loadmodule': 4,'perl': 4,
                            'rootkit': 4,'ps': 4,'sqlattack': 4,'xterm': 4})

frame_test
# Out:
# 0        1
# 1        1
# 2        0
# 3        2
# 4        2
#         ..
# 22539    0
# 22540    0
# 22541    1
# 22542    0
# 22543    2
# Name: class, Length: 22544, dtype: int64

# %%
train_df['class'] = frame_train
train_df
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 125968         0           tcp   private   S0          0          0     0
# 125969         8           udp   private   SF        105        145     0
# 125970         0           tcp      smtp   SF       2231        384     0
# 125971         0           tcp    klogin   S0          0          0     0
# 125972         0           tcp  ftp_data   SF        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0                    0       0    0  ...                    0.17
# 1                    0       0    0  ...                    0.00
# 2                    0       0    0  ...                    0.10
# 3                    0       0    0  ...                    1.00
# 4                    0       0    0  ...                    1.00
# ...                ...     ...  ...  ...                     ...
# 125968               0       0    0  ...                    0.10
# 125969               0       0    0  ...                    0.96
# 125970               0       0    0  ...                    0.12
# 125971               0       0    0  ...                    0.03
# 125972               0       0    0  ...                    0.30
#
#         dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                         0.03                         0.17
# 1                         0.60                         0.88
# 2                         0.05                         0.00
# 3                         0.00                         0.03
# 4                         0.00                         0.00
# ...                        ...                          ...
# 125968                    0.06                         0.00
# 125969                    0.01                         0.01
# 125970                    0.06                         0.00
# 125971                    0.05                         0.00
# 125972                    0.03                         0.30
#
#         dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                              0.00                  0.00
# 1                              0.00                  0.00
# 2                              0.00                  1.00
# 3                              0.04                  0.03
# 4                              0.00                  0.00
# ...                             ...                   ...
# 125968                         0.00                  1.00
# 125969                         0.00                  0.00
# 125970                         0.00                  0.72
# 125971                         0.00                  1.00
# 125972                         0.00                  0.00
#
#         dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                           0.00                  0.05
# 1                           0.00                  0.00
# 2                           1.00                  0.00
# 3                           0.01                  0.00
# 4                           0.00                  0.00
# ...                          ...                   ...
# 125968                      1.00                  0.00
# 125969                      0.00                  0.00
# 125970                      0.00                  0.01
# 125971                      1.00                  0.00
# 125972                      0.00                  0.00
#
#         dst_host_srv_rerror_rate  class  severity_score
# 0                           0.00      0              20
# 1                           0.00      0              15
# 2                           0.00      1              19
# 3                           0.01      0              21
# 4                           0.00      0              21
# ...                          ...    ...             ...
# 125968                      0.00      1              20
# 125969                      0.00      0              21
# 125970                      0.00      0              18
# 125971                      0.00      1              20
# 125972                      0.00      0              21
#
# [125973 rows x 43 columns]

# %%
test_df['class'] = frame_test
test_df
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   private   REJ          0          0     0
# 1             0           tcp   private   REJ          0          0     0
# 2             2           tcp  ftp_data    SF      12983          0     0
# 3             0          icmp     eco_i    SF         20          0     0
# 4             1           tcp    telnet  RSTO          0         15     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 22539         0           tcp      smtp    SF        794        333     0
# 22540         0           tcp      http    SF        317        938     0
# 22541         0           tcp      http    SF      54540       8314     0
# 22542         0           udp  domain_u    SF         42         42     0
# 22543         0           tcp    sunrpc   REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0                   0       0    0  ...                    0.04
# 1                   0       0    0  ...                    0.00
# 2                   0       0    0  ...                    0.61
# 3                   0       0    0  ...                    1.00
# 4                   0       0    0  ...                    0.31
# ...               ...     ...  ...  ...                     ...
# 22539               0       0    0  ...                    0.72
# 22540               0       0    0  ...                    1.00
# 22541               0       0    2  ...                    1.00
# 22542               0       0    0  ...                    0.99
# 22543               0       0    0  ...                    0.08
#
#        dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                        0.06                         0.00
# 1                        0.06                         0.00
# 2                        0.04                         0.61
# 3                        0.00                         1.00
# 4                        0.17                         0.03
# ...                       ...                          ...
# 22539                    0.06                         0.01
# 22540                    0.00                         0.01
# 22541                    0.00                         0.00
# 22542                    0.01                         0.00
# 22543                    0.03                         0.00
#
#        dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                             0.00                  0.00
# 1                             0.00                  0.00
# 2                             0.02                  0.00
# 3                             0.28                  0.00
# 4                             0.02                  0.00
# ...                            ...                   ...
# 22539                         0.01                  0.01
# 22540                         0.01                  0.01
# 22541                         0.00                  0.00
# 22542                         0.00                  0.00
# 22543                         0.00                  0.00
#
#        dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                           0.0                  1.00
# 1                           0.0                  1.00
# 2                           0.0                  0.00
# 3                           0.0                  0.00
# 4                           0.0                  0.83
# ...                         ...                   ...
# 22539                       0.0                  0.00
# 22540                       0.0                  0.00
# 22541                       0.0                  0.07
# 22542                       0.0                  0.00
# 22543                       0.0                  0.44
#
#        dst_host_srv_rerror_rate  class  severity_score
# 0                          1.00      1              21
# 1                          1.00      1              21
# 2                          0.00      0              21
# 3                          0.00      2              15
# 4                          0.71      2              11
# ...                         ...    ...             ...
# 22539                      0.00      0              21
# 22540                      0.00      0              21
# 22541                      0.07      1              15
# 22542                      0.00      0              21
# 22543                      1.00      2              14
#
# [22544 rows x 43 columns]

# %%
train_df = train_df.drop(['severity_score'], axis = 1)
train_df
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 125968         0           tcp   private   S0          0          0     0
# 125969         8           udp   private   SF        105        145     0
# 125970         0           tcp      smtp   SF       2231        384     0
# 125971         0           tcp    klogin   S0          0          0     0
# 125972         0           tcp  ftp_data   SF        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                    0       0    0  ...                  25
# 1                    0       0    0  ...                   1
# 2                    0       0    0  ...                  26
# 3                    0       0    0  ...                 255
# 4                    0       0    0  ...                 255
# ...                ...     ...  ...  ...                 ...
# 125968               0       0    0  ...                  25
# 125969               0       0    0  ...                 244
# 125970               0       0    0  ...                  30
# 125971               0       0    0  ...                   8
# 125972               0       0    0  ...                  77
#
#         dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                         0.17                    0.03
# 1                         0.00                    0.60
# 2                         0.10                    0.05
# 3                         1.00                    0.00
# 4                         1.00                    0.00
# ...                        ...                     ...
# 125968                    0.10                    0.06
# 125969                    0.96                    0.01
# 125970                    0.12                    0.06
# 125971                    0.03                    0.05
# 125972                    0.30                    0.03
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                              0.17                         0.00
# 1                              0.88                         0.00
# 2                              0.00                         0.00
# 3                              0.03                         0.04
# 4                              0.00                         0.00
# ...                             ...                          ...
# 125968                         0.00                         0.00
# 125969                         0.01                         0.00
# 125970                         0.00                         0.00
# 125971                         0.00                         0.00
# 125972                         0.30                         0.00
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                       0.00                      0.00                  0.05
# 1                       0.00                      0.00                  0.00
# 2                       1.00                      1.00                  0.00
# 3                       0.03                      0.01                  0.00
# 4                       0.00                      0.00                  0.00
# ...                      ...                       ...                   ...
# 125968                  1.00                      1.00                  0.00
# 125969                  0.00                      0.00                  0.00
# 125970                  0.72                      0.00                  0.01
# 125971                  1.00                      1.00                  0.00
# 125972                  0.00                      0.00                  0.00
#
#         dst_host_srv_rerror_rate  class
# 0                           0.00      0
# 1                           0.00      0
# 2                           0.00      1
# 3                           0.01      0
# 4                           0.00      0
# ...                          ...    ...
# 125968                      0.00      1
# 125969                      0.00      0
# 125970                      0.00      0
# 125971                      0.00      1
# 125972                      0.00      0
#
# [125973 rows x 42 columns]

# %%
test_df = test_df.drop(['severity_score'], axis = 1)
test_df
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   private   REJ          0          0     0
# 1             0           tcp   private   REJ          0          0     0
# 2             2           tcp  ftp_data    SF      12983          0     0
# 3             0          icmp     eco_i    SF         20          0     0
# 4             1           tcp    telnet  RSTO          0         15     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 22539         0           tcp      smtp    SF        794        333     0
# 22540         0           tcp      http    SF        317        938     0
# 22541         0           tcp      http    SF      54540       8314     0
# 22542         0           udp  domain_u    SF         42         42     0
# 22543         0           tcp    sunrpc   REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                   0       0    0  ...                  10
# 1                   0       0    0  ...                   1
# 2                   0       0    0  ...                  86
# 3                   0       0    0  ...                  57
# 4                   0       0    0  ...                  86
# ...               ...     ...  ...  ...                 ...
# 22539               0       0    0  ...                 141
# 22540               0       0    0  ...                 255
# 22541               0       0    2  ...                 255
# 22542               0       0    0  ...                 252
# 22543               0       0    0  ...                  21
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                        0.04                    0.06
# 1                        0.00                    0.06
# 2                        0.61                    0.04
# 3                        1.00                    0.00
# 4                        0.31                    0.17
# ...                       ...                     ...
# 22539                    0.72                    0.06
# 22540                    1.00                    0.00
# 22541                    1.00                    0.00
# 22542                    0.99                    0.01
# 22543                    0.08                    0.03
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                             0.00                         0.00
# 1                             0.00                         0.00
# 2                             0.61                         0.02
# 3                             1.00                         0.28
# 4                             0.03                         0.02
# ...                            ...                          ...
# 22539                         0.01                         0.01
# 22540                         0.01                         0.01
# 22541                         0.00                         0.00
# 22542                         0.00                         0.00
# 22543                         0.00                         0.00
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      0.00                       0.0                  1.00
# 1                      0.00                       0.0                  1.00
# 2                      0.00                       0.0                  0.00
# 3                      0.00                       0.0                  0.00
# 4                      0.00                       0.0                  0.83
# ...                     ...                       ...                   ...
# 22539                  0.01                       0.0                  0.00
# 22540                  0.01                       0.0                  0.00
# 22541                  0.00                       0.0                  0.07
# 22542                  0.00                       0.0                  0.00
# 22543                  0.00                       0.0                  0.44
#
#        dst_host_srv_rerror_rate  class
# 0                          1.00      1
# 1                          1.00      1
# 2                          0.00      0
# 3                          0.00      2
# 4                          0.71      2
# ...                         ...    ...
# 22539                      0.00      0
# 22540                      0.00      0
# 22541                      0.07      1
# 22542                      0.00      0
# 22543                      1.00      2
#
# [22544 rows x 42 columns]

# %%
#converting the categorical values into numerical values - protocol_type, service and flag 
# for train
train_df.protocol_type = le.fit_transform(train_df.protocol_type)
train_df.service = le.fit_transform(train_df.service)
train_df.flag = le.fit_transform(train_df.flag)

train_df.protocol_type = train_df.protocol_type.astype('category')
train_df.service = train_df.service.astype('category')
train_df.flag = train_df.flag.astype('category')

train_df.describe(include='all')
# Out:
#             duration  protocol_type   service      flag     src_bytes  \
# count   125973.00000       125973.0  125973.0  125973.0  1.259730e+05
# unique           NaN            3.0      70.0      11.0           NaN
# top              NaN            1.0      24.0       9.0           NaN
# freq             NaN       102689.0   40338.0   74945.0           NaN
# mean       287.14465            NaN       NaN       NaN  4.556674e+04
# std       2604.51531            NaN       NaN       NaN  5.870331e+06
# min          0.00000            NaN       NaN       NaN  0.000000e+00
# 25%          0.00000            NaN       NaN       NaN  0.000000e+00
# 50%          0.00000            NaN       NaN       NaN  4.400000e+01
# 75%          0.00000            NaN       NaN       NaN  2.760000e+02
# max      42908.00000            NaN       NaN       NaN  1.379964e+09
#
#            dst_bytes           land  wrong_fragment         urgent  \
# count   1.259730e+05  125973.000000   125973.000000  125973.000000
# unique           NaN            NaN             NaN            NaN
# top              NaN            NaN             NaN            NaN
# freq             NaN            NaN             NaN            NaN
# mean    1.977911e+04       0.000198        0.022687       0.000111
# std     4.021269e+06       0.014086        0.253530       0.014366
# min     0.000000e+00       0.000000        0.000000       0.000000
# 25%     0.000000e+00       0.000000        0.000000       0.000000
# 50%     0.000000e+00       0.000000        0.000000       0.000000
# 75%     5.160000e+02       0.000000        0.000000       0.000000
# max     1.309937e+09       1.000000        3.000000       3.000000
#
#                   hot  ...  dst_host_srv_count  dst_host_same_srv_rate  \
# count   125973.000000  ...       125973.000000           125973.000000
# unique            NaN  ...                 NaN                     NaN
# top               NaN  ...                 NaN                     NaN
# freq              NaN  ...                 NaN                     NaN
# mean         0.204409  ...          115.653005                0.521242
# std          2.149968  ...          110.702741                0.448949
# min          0.000000  ...            0.000000                0.000000
# 25%          0.000000  ...           10.000000                0.050000
# 50%          0.000000  ...           63.000000                0.510000
# 75%          0.000000  ...          255.000000                1.000000
# max         77.000000  ...          255.000000                1.000000
#
#         dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# count            125973.000000                125973.000000
# unique                     NaN                          NaN
# top                        NaN                          NaN
# freq                       NaN                          NaN
# mean                  0.082951                     0.148379
# std                   0.188922                     0.308997
# min                   0.000000                     0.000000
# 25%                   0.000000                     0.000000
# 50%                   0.020000                     0.000000
# 75%                   0.070000                     0.060000
# max                   1.000000                     1.000000
#
#         dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# count                 125973.000000         125973.000000
# unique                          NaN                   NaN
# top                             NaN                   NaN
# freq                            NaN                   NaN
# mean                       0.032542              0.284452
# std                        0.112564              0.444784
# min                        0.000000              0.000000
# 25%                        0.000000              0.000000
# 50%                        0.000000              0.000000
# 75%                        0.020000              1.000000
# max                        1.000000              1.000000
#
#         dst_host_srv_serror_rate  dst_host_rerror_rate  \
# count              125973.000000         125973.000000
# unique                       NaN                   NaN
# top                          NaN                   NaN
# freq                         NaN                   NaN
# mean                    0.278485              0.118832
# std                     0.445669              0.306557
# min                     0.000000              0.000000
# 25%                     0.000000              0.000000
# 50%                     0.000000              0.000000
# 75%                     1.000000              0.000000
# max                     1.000000              1.000000
#
#         dst_host_srv_rerror_rate          class
# count              125973.000000  125973.000000
# unique                       NaN            NaN
# top                          NaN            NaN
# freq                         NaN            NaN
# mean                    0.120240       0.574980
# std                     0.319459       0.694105
# min                     0.000000       0.000000
# 25%                     0.000000       0.000000
# 50%                     0.000000       0.000000
# 75%                     0.000000       1.000000
# max                     1.000000       4.000000
#
# [11 rows x 42 columns]

# %%
train_df
# Out:
#         duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 0              0             1      20    9        491          0     0
# 1              0             2      44    9        146          0     0
# 2              0             1      49    5          0          0     0
# 3              0             1      24    9        232       8153     0
# 4              0             1      24    9        199        420     0
# ...          ...           ...     ...  ...        ...        ...   ...
# 125968         0             1      49    5          0          0     0
# 125969         8             2      49    9        105        145     0
# 125970         0             1      54    9       2231        384     0
# 125971         0             1      30    5          0          0     0
# 125972         0             1      20    9        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                    0       0    0  ...                  25
# 1                    0       0    0  ...                   1
# 2                    0       0    0  ...                  26
# 3                    0       0    0  ...                 255
# 4                    0       0    0  ...                 255
# ...                ...     ...  ...  ...                 ...
# 125968               0       0    0  ...                  25
# 125969               0       0    0  ...                 244
# 125970               0       0    0  ...                  30
# 125971               0       0    0  ...                   8
# 125972               0       0    0  ...                  77
#
#         dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                         0.17                    0.03
# 1                         0.00                    0.60
# 2                         0.10                    0.05
# 3                         1.00                    0.00
# 4                         1.00                    0.00
# ...                        ...                     ...
# 125968                    0.10                    0.06
# 125969                    0.96                    0.01
# 125970                    0.12                    0.06
# 125971                    0.03                    0.05
# 125972                    0.30                    0.03
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                              0.17                         0.00
# 1                              0.88                         0.00
# 2                              0.00                         0.00
# 3                              0.03                         0.04
# 4                              0.00                         0.00
# ...                             ...                          ...
# 125968                         0.00                         0.00
# 125969                         0.01                         0.00
# 125970                         0.00                         0.00
# 125971                         0.00                         0.00
# 125972                         0.30                         0.00
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                       0.00                      0.00                  0.05
# 1                       0.00                      0.00                  0.00
# 2                       1.00                      1.00                  0.00
# 3                       0.03                      0.01                  0.00
# 4                       0.00                      0.00                  0.00
# ...                      ...                       ...                   ...
# 125968                  1.00                      1.00                  0.00
# 125969                  0.00                      0.00                  0.00
# 125970                  0.72                      0.00                  0.01
# 125971                  1.00                      1.00                  0.00
# 125972                  0.00                      0.00                  0.00
#
#         dst_host_srv_rerror_rate  class
# 0                           0.00      0
# 1                           0.00      0
# 2                           0.00      1
# 3                           0.01      0
# 4                           0.00      0
# ...                          ...    ...
# 125968                      0.00      1
# 125969                      0.00      0
# 125970                      0.00      0
# 125971                      0.00      1
# 125972                      0.00      0
#
# [125973 rows x 42 columns]

# %%
#converting the categorical values into numerical values - protocol_type, service and flag 
# for test
test_df.protocol_type = le.fit_transform(test_df.protocol_type)
test_df.service = le.fit_transform(test_df.service)
test_df.flag = le.fit_transform(test_df.flag)

test_df.protocol_type = test_df.protocol_type.astype('category')
test_df.service = test_df.service.astype('category')
test_df.flag = test_df.flag.astype('category')

test_df.describe(include='all')
# Out:
#             duration  protocol_type  service     flag     src_bytes  \
# count   22544.000000        22544.0  22544.0  22544.0  2.254400e+04
# unique           NaN            3.0     64.0     11.0           NaN
# top              NaN            1.0     22.0      9.0           NaN
# freq             NaN        18880.0   7853.0  14875.0           NaN
# mean      218.859076            NaN      NaN      NaN  1.039545e+04
# std      1407.176612            NaN      NaN      NaN  4.727864e+05
# min         0.000000            NaN      NaN      NaN  0.000000e+00
# 25%         0.000000            NaN      NaN      NaN  0.000000e+00
# 50%         0.000000            NaN      NaN      NaN  5.400000e+01
# 75%         0.000000            NaN      NaN      NaN  2.870000e+02
# max     57715.000000            NaN      NaN      NaN  6.282565e+07
#
#            dst_bytes          land  wrong_fragment        urgent  \
# count   2.254400e+04  22544.000000    22544.000000  22544.000000
# unique           NaN           NaN             NaN           NaN
# top              NaN           NaN             NaN           NaN
# freq             NaN           NaN             NaN           NaN
# mean    2.056019e+03      0.000311        0.008428      0.000710
# std     2.121930e+04      0.017619        0.142599      0.036473
# min     0.000000e+00      0.000000        0.000000      0.000000
# 25%     0.000000e+00      0.000000        0.000000      0.000000
# 50%     4.600000e+01      0.000000        0.000000      0.000000
# 75%     6.010000e+02      0.000000        0.000000      0.000000
# max     1.345927e+06      1.000000        3.000000      3.000000
#
#                  hot  ...  dst_host_srv_count  dst_host_same_srv_rate  \
# count   22544.000000  ...        22544.000000            22544.000000
# unique           NaN  ...                 NaN                     NaN
# top              NaN  ...                 NaN                     NaN
# freq             NaN  ...                 NaN                     NaN
# mean        0.105394  ...          140.750532                0.608722
# std         0.928428  ...          111.783972                0.435688
# min         0.000000  ...            0.000000                0.000000
# 25%         0.000000  ...           15.000000                0.070000
# 50%         0.000000  ...          168.000000                0.920000
# 75%         0.000000  ...          255.000000                1.000000
# max       101.000000  ...          255.000000                1.000000
#
#         dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# count             22544.000000                 22544.000000
# unique                     NaN                          NaN
# top                        NaN                          NaN
# freq                       NaN                          NaN
# mean                  0.090540                     0.132261
# std                   0.220717                     0.306268
# min                   0.000000                     0.000000
# 25%                   0.000000                     0.000000
# 50%                   0.010000                     0.000000
# 75%                   0.060000                     0.030000
# max                   1.000000                     1.000000
#
#         dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# count                  22544.000000          22544.000000
# unique                          NaN                   NaN
# top                             NaN                   NaN
# freq                            NaN                   NaN
# mean                       0.019638              0.097814
# std                        0.085394              0.273139
# min                        0.000000              0.000000
# 25%                        0.000000              0.000000
# 50%                        0.000000              0.000000
# 75%                        0.010000              0.000000
# max                        1.000000              1.000000
#
#         dst_host_srv_serror_rate  dst_host_rerror_rate  \
# count               22544.000000          22544.000000
# unique                       NaN                   NaN
# top                          NaN                   NaN
# freq                         NaN                   NaN
# mean                    0.099426              0.233385
# std                     0.281866              0.387229
# min                     0.000000              0.000000
# 25%                     0.000000              0.000000
# 50%                     0.000000              0.000000
# 75%                     0.000000              0.360000
# max                     1.000000              1.000000
#
#         dst_host_srv_rerror_rate         class
# count               22544.000000  22544.000000
# unique                       NaN           NaN
# top                          NaN           NaN
# freq                         NaN           NaN
# mean                    0.226683      0.941492
# std                     0.400875      1.036054
# min                     0.000000      0.000000
# 25%                     0.000000      0.000000
# 50%                     0.000000      1.000000
# 75%                     0.170000      1.000000
# max                     1.000000      4.000000
#
# [11 rows x 42 columns]

# %%
test_df
# Out:
#        duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 0             0             1      45    1          0          0     0
# 1             0             1      45    1          0          0     0
# 2             2             1      19    9      12983          0     0
# 3             0             0      13    9         20          0     0
# 4             1             1      55    2          0         15     0
# ...         ...           ...     ...  ...        ...        ...   ...
# 22539         0             1      49    9        794        333     0
# 22540         0             1      22    9        317        938     0
# 22541         0             1      22    9      54540       8314     0
# 22542         0             2      11    9         42         42     0
# 22543         0             1      52    1          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                   0       0    0  ...                  10
# 1                   0       0    0  ...                   1
# 2                   0       0    0  ...                  86
# 3                   0       0    0  ...                  57
# 4                   0       0    0  ...                  86
# ...               ...     ...  ...  ...                 ...
# 22539               0       0    0  ...                 141
# 22540               0       0    0  ...                 255
# 22541               0       0    2  ...                 255
# 22542               0       0    0  ...                 252
# 22543               0       0    0  ...                  21
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                        0.04                    0.06
# 1                        0.00                    0.06
# 2                        0.61                    0.04
# 3                        1.00                    0.00
# 4                        0.31                    0.17
# ...                       ...                     ...
# 22539                    0.72                    0.06
# 22540                    1.00                    0.00
# 22541                    1.00                    0.00
# 22542                    0.99                    0.01
# 22543                    0.08                    0.03
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                             0.00                         0.00
# 1                             0.00                         0.00
# 2                             0.61                         0.02
# 3                             1.00                         0.28
# 4                             0.03                         0.02
# ...                            ...                          ...
# 22539                         0.01                         0.01
# 22540                         0.01                         0.01
# 22541                         0.00                         0.00
# 22542                         0.00                         0.00
# 22543                         0.00                         0.00
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      0.00                       0.0                  1.00
# 1                      0.00                       0.0                  1.00
# 2                      0.00                       0.0                  0.00
# 3                      0.00                       0.0                  0.00
# 4                      0.00                       0.0                  0.83
# ...                     ...                       ...                   ...
# 22539                  0.01                       0.0                  0.00
# 22540                  0.01                       0.0                  0.00
# 22541                  0.00                       0.0                  0.07
# 22542                  0.00                       0.0                  0.00
# 22543                  0.00                       0.0                  0.44
#
#        dst_host_srv_rerror_rate  class
# 0                          1.00      1
# 1                          1.00      1
# 2                          0.00      0
# 3                          0.00      2
# 4                          0.71      2
# ...                         ...    ...
# 22539                      0.00      0
# 22540                      0.00      0
# 22541                      0.07      1
# 22542                      0.00      0
# 22543                      1.00      2
#
# [22544 rows x 42 columns]

# %%
# Rename every attack label: 0=normal, 1=DoS, 2=Probe, 3=R2L and 4=U2R.
#for-train
to_keep_dos=[0,1]
to_keep_probe=[0,2]
to_keep_r2l=[0,3]
to_keep_u2r=[0,4]
dos_df=train_df[train_df['class'].isin(to_keep_dos)];
probe_df=train_df[train_df['class'].isin(to_keep_probe)];
r2l_df=train_df[train_df['class'].isin(to_keep_r2l)];
u2r_df=train_df[train_df['class'].isin(to_keep_u2r)];

dos_df
# Out:
#         duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 0              0             1      20    9        491          0     0
# 1              0             2      44    9        146          0     0
# 2              0             1      49    5          0          0     0
# 3              0             1      24    9        232       8153     0
# 4              0             1      24    9        199        420     0
# ...          ...           ...     ...  ...        ...        ...   ...
# 125968         0             1      49    5          0          0     0
# 125969         8             2      49    9        105        145     0
# 125970         0             1      54    9       2231        384     0
# 125971         0             1      30    5          0          0     0
# 125972         0             1      20    9        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                    0       0    0  ...                  25
# 1                    0       0    0  ...                   1
# 2                    0       0    0  ...                  26
# 3                    0       0    0  ...                 255
# 4                    0       0    0  ...                 255
# ...                ...     ...  ...  ...                 ...
# 125968               0       0    0  ...                  25
# 125969               0       0    0  ...                 244
# 125970               0       0    0  ...                  30
# 125971               0       0    0  ...                   8
# 125972               0       0    0  ...                  77
#
#         dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                         0.17                    0.03
# 1                         0.00                    0.60
# 2                         0.10                    0.05
# 3                         1.00                    0.00
# 4                         1.00                    0.00
# ...                        ...                     ...
# 125968                    0.10                    0.06
# 125969                    0.96                    0.01
# 125970                    0.12                    0.06
# 125971                    0.03                    0.05
# 125972                    0.30                    0.03
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                              0.17                         0.00
# 1                              0.88                         0.00
# 2                              0.00                         0.00
# 3                              0.03                         0.04
# 4                              0.00                         0.00
# ...                             ...                          ...
# 125968                         0.00                         0.00
# 125969                         0.01                         0.00
# 125970                         0.00                         0.00
# 125971                         0.00                         0.00
# 125972                         0.30                         0.00
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                       0.00                      0.00                  0.05
# 1                       0.00                      0.00                  0.00
# 2                       1.00                      1.00                  0.00
# 3                       0.03                      0.01                  0.00
# 4                       0.00                      0.00                  0.00
# ...                      ...                       ...                   ...
# 125968                  1.00                      1.00                  0.00
# 125969                  0.00                      0.00                  0.00
# 125970                  0.72                      0.00                  0.01
# 125971                  1.00                      1.00                  0.00
# 125972                  0.00                      0.00                  0.00
#
#         dst_host_srv_rerror_rate  class
# 0                           0.00      0
# 1                           0.00      0
# 2                           0.00      1
# 3                           0.01      0
# 4                           0.00      0
# ...                          ...    ...
# 125968                      0.00      1
# 125969                      0.00      0
# 125970                      0.00      0
# 125971                      0.00      1
# 125972                      0.00      0
#
# [113270 rows x 42 columns]

# %%
# Rename every attack label: 0=normal, 1=DoS, 2=Probe, 3=R2L and 4=U2R.
#for-test

dos_df_test=test_df[test_df['class'].isin(to_keep_dos)];
probe_df_test=test_df[test_df['class'].isin(to_keep_probe)];
r2l_df_test=test_df[test_df['class'].isin(to_keep_r2l)];
u2r_df_test=test_df[test_df['class'].isin(to_keep_u2r)];

u2r_df_test
# Out:
#        duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 2             2             1      19    9      12983          0     0
# 5             0             1      22    9        267      14515     0
# 6             0             1      49    9       1022        387     0
# 8             0             1      22    9        327        467     0
# 11            0             1      49    9        616        330     0
# ...         ...           ...     ...  ...        ...        ...   ...
# 22533         0             1      22    9        274       1623     0
# 22535         0             1      22    9        280       6087     0
# 22539         0             1      49    9        794        333     0
# 22540         0             1      22    9        317        938     0
# 22542         0             2      11    9         42         42     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 2                   0       0    0  ...                  86
# 5                   0       0    0  ...                 255
# 6                   0       0    0  ...                  28
# 8                   0       0    0  ...                 255
# 11                  0       0    0  ...                 129
# ...               ...     ...  ...  ...                 ...
# 22533               0       0    0  ...                 255
# 22535               0       0    0  ...                 255
# 22539               0       0    0  ...                 141
# 22540               0       0    0  ...                 255
# 22542               0       0    0  ...                 252
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 2                        0.61                    0.04
# 5                        1.00                    0.00
# 6                        0.11                    0.72
# 8                        1.00                    0.00
# 11                       0.51                    0.03
# ...                       ...                     ...
# 22533                    1.00                    0.00
# 22535                    1.00                    0.00
# 22539                    0.72                    0.06
# 22540                    1.00                    0.00
# 22542                    0.99                    0.01
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 2                             0.61                         0.02
# 5                             0.01                         0.03
# 6                             0.00                         0.00
# 8                             0.01                         0.03
# 11                            0.00                         0.00
# ...                            ...                          ...
# 22533                         0.01                         0.04
# 22535                         0.20                         0.04
# 22539                         0.01                         0.01
# 22540                         0.01                         0.01
# 22542                         0.00                         0.00
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 2                      0.00                       0.0                  0.00
# 5                      0.01                       0.0                  0.00
# 6                      0.00                       0.0                  0.72
# 8                      0.00                       0.0                  0.00
# 11                     0.00                       0.0                  0.33
# ...                     ...                       ...                   ...
# 22533                  0.00                       0.0                  0.00
# 22535                  0.00                       0.0                  0.00
# 22539                  0.01                       0.0                  0.00
# 22540                  0.01                       0.0                  0.00
# 22542                  0.00                       0.0                  0.00
#
#        dst_host_srv_rerror_rate  class
# 2                          0.00      0
# 5                          0.00      0
# 6                          0.04      0
# 8                          0.00      0
# 11                         0.00      0
# ...                         ...    ...
# 22533                      0.00      0
# 22535                      0.00      0
# 22539                      0.00      0
# 22540                      0.00      0
# 22542                      0.00      0
#
# [9778 rows x 42 columns]

# %%
# Split dataframes into X & Y
# assign X as a dataframe of feautures and Y as a series of outcome variables
X_train_dos = dos_df.drop('class',1)
Y_train_dos = dos_df['class']
X_train_probe = probe_df.drop('class',1)
Y_train_probe = probe_df['class']
X_train_r2l = r2l_df.drop('class',1)
Y_train_r2l = r2l_df['class']
X_train_u2r = u2r_df.drop('class',1)
Y_train_u2r = u2r_df['class']

X_train_dos
# Out:
#         duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 0              0             1      20    9        491          0     0
# 1              0             2      44    9        146          0     0
# 2              0             1      49    5          0          0     0
# 3              0             1      24    9        232       8153     0
# 4              0             1      24    9        199        420     0
# ...          ...           ...     ...  ...        ...        ...   ...
# 125968         0             1      49    5          0          0     0
# 125969         8             2      49    9        105        145     0
# 125970         0             1      54    9       2231        384     0
# 125971         0             1      30    5          0          0     0
# 125972         0             1      20    9        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# 0                    0       0    0  ...             150                  25
# 1                    0       0    0  ...             255                   1
# 2                    0       0    0  ...             255                  26
# 3                    0       0    0  ...              30                 255
# 4                    0       0    0  ...             255                 255
# ...                ...     ...  ...  ...             ...                 ...
# 125968               0       0    0  ...             255                  25
# 125969               0       0    0  ...             255                 244
# 125970               0       0    0  ...             255                  30
# 125971               0       0    0  ...             255                   8
# 125972               0       0    0  ...             255                  77
#
#         dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                         0.17                    0.03
# 1                         0.00                    0.60
# 2                         0.10                    0.05
# 3                         1.00                    0.00
# 4                         1.00                    0.00
# ...                        ...                     ...
# 125968                    0.10                    0.06
# 125969                    0.96                    0.01
# 125970                    0.12                    0.06
# 125971                    0.03                    0.05
# 125972                    0.30                    0.03
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                              0.17                         0.00
# 1                              0.88                         0.00
# 2                              0.00                         0.00
# 3                              0.03                         0.04
# 4                              0.00                         0.00
# ...                             ...                          ...
# 125968                         0.00                         0.00
# 125969                         0.01                         0.00
# 125970                         0.00                         0.00
# 125971                         0.00                         0.00
# 125972                         0.30                         0.00
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                       0.00                      0.00                  0.05
# 1                       0.00                      0.00                  0.00
# 2                       1.00                      1.00                  0.00
# 3                       0.03                      0.01                  0.00
# 4                       0.00                      0.00                  0.00
# ...                      ...                       ...                   ...
# 125968                  1.00                      1.00                  0.00
# 125969                  0.00                      0.00                  0.00
# 125970                  0.72                      0.00                  0.01
# 125971                  1.00                      1.00                  0.00
# 125972                  0.00                      0.00                  0.00
#
#         dst_host_srv_rerror_rate
# 0                           0.00
# 1                           0.00
# 2                           0.00
# 3                           0.01
# 4                           0.00
# ...                          ...
# 125968                      0.00
# 125969                      0.00
# 125970                      0.00
# 125971                      0.00
# 125972                      0.00
#
# [113270 rows x 41 columns]

# %%
# Split dataframes into X & Y
# assign X as a dataframe of feautures and Y as a series of outcome variables
X_test_dos = dos_df_test.drop('class',1)
Y_test_dos = dos_df_test['class']
X_test_probe = probe_df_test.drop('class',1)
Y_test_probe = probe_df_test['class']
X_test_r2l = r2l_df_test.drop('class',1)
Y_test_r2l = r2l_df_test['class']
X_test_u2r = u2r_df_test.drop('class',1)
Y_test_u2r = u2r_df_test['class']

X_test_dos
# Out:
#        duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 0             0             1      45    1          0          0     0
# 1             0             1      45    1          0          0     0
# 2             2             1      19    9      12983          0     0
# 5             0             1      22    9        267      14515     0
# 6             0             1      49    9       1022        387     0
# ...         ...           ...     ...  ...        ...        ...   ...
# 22538         0             0      14    9       1032          0     0
# 22539         0             1      49    9        794        333     0
# 22540         0             1      22    9        317        938     0
# 22541         0             1      22    9      54540       8314     0
# 22542         0             2      11    9         42         42     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# 0                   0       0    0  ...             255                  10
# 1                   0       0    0  ...             255                   1
# 2                   0       0    0  ...             134                  86
# 5                   0       0    0  ...             155                 255
# 6                   0       0    0  ...             255                  28
# ...               ...     ...  ...  ...             ...                 ...
# 22538               0       0    0  ...             255                 255
# 22539               0       0    0  ...             100                 141
# 22540               0       0    0  ...             197                 255
# 22541               0       0    2  ...             255                 255
# 22542               0       0    0  ...             255                 252
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                        0.04                    0.06
# 1                        0.00                    0.06
# 2                        0.61                    0.04
# 5                        1.00                    0.00
# 6                        0.11                    0.72
# ...                       ...                     ...
# 22538                    1.00                    0.00
# 22539                    0.72                    0.06
# 22540                    1.00                    0.00
# 22541                    1.00                    0.00
# 22542                    0.99                    0.01
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                             0.00                         0.00
# 1                             0.00                         0.00
# 2                             0.61                         0.02
# 5                             0.01                         0.03
# 6                             0.00                         0.00
# ...                            ...                          ...
# 22538                         1.00                         0.00
# 22539                         0.01                         0.01
# 22540                         0.01                         0.01
# 22541                         0.00                         0.00
# 22542                         0.00                         0.00
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      0.00                       0.0                  1.00
# 1                      0.00                       0.0                  1.00
# 2                      0.00                       0.0                  0.00
# 5                      0.01                       0.0                  0.00
# 6                      0.00                       0.0                  0.72
# ...                     ...                       ...                   ...
# 22538                  0.00                       0.0                  0.00
# 22539                  0.01                       0.0                  0.00
# 22540                  0.01                       0.0                  0.00
# 22541                  0.00                       0.0                  0.07
# 22542                  0.00                       0.0                  0.00
#
#        dst_host_srv_rerror_rate
# 0                          1.00
# 1                          1.00
# 2                          0.00
# 5                          0.00
# 6                          0.04
# ...                         ...
# 22538                      0.00
# 22539                      0.00
# 22540                      0.00
# 22541                      0.07
# 22542                      0.00
#
# [17171 rows x 41 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %%
#clf_random = RandomForestClassifier(max_depth=20, random_state=0)
clf_random_dos = RandomForestClassifier(max_depth = 25,random_state=0)

# %%
clf_random_dos.fit(X_train_dos,Y_train_dos)
# Out:
# RandomForestClassifier(max_depth=25, random_state=0)

# %%
Y_pred_random_dos=clf_random_dos.predict(X_test_dos)

# %%
random_df = pd.DataFrame({'Actual': Y_test_dos, 'Predicted': Y_pred_random_dos})

# %%
metrics.mean_absolute_error(Y_test_dos,Y_pred_random_dos)
# Out:
# 0.1002853648593559

# %%
metrics.accuracy_score(Y_test_dos,Y_pred_random_dos)
# Out:
# 0.8997146351406441

# %%
metrics.precision_recall_fscore_support(Y_test_dos,Y_pred_random_dos, average='weighted')
# Out:
# (0.9117669995161105, 0.8997146351406441, 0.8975798077270299, None)

# %%
#clf_random = RandomForestClassifier(max_depth=20, random_state=0)
clf_random_probe = RandomForestClassifier(max_depth = 25,random_state=0)
clf_random_probe.fit(X_train_probe,Y_train_probe)
Y_pred_random_probe=clf_random_probe.predict(X_test_probe)
random_df = pd.DataFrame({'Actual': Y_test_probe, 'Predicted': Y_pred_random_probe})

# %%
metrics.mean_absolute_error(Y_test_probe,Y_pred_random_probe)
# Out:
# 0.19287833827893175

# %%
metrics.accuracy_score(Y_test_probe,Y_pred_random_probe)
# Out:
# 0.9035608308605341

# %%
metrics.precision_recall_fscore_support(Y_test_probe,Y_pred_random_probe, average='weighted')
# Out:
# (0.9018354077901943, 0.9035608308605341, 0.8962106562402289, None)

# %%
#clf_random = RandomForestClassifier(max_depth=20, random_state=0)
clf_random_r2l = RandomForestClassifier(max_depth = 25,random_state=0)
clf_random_r2l.fit(X_train_r2l,Y_train_r2l)
Y_pred_random_r2l=clf_random_r2l.predict(X_test_r2l)
random_df = pd.DataFrame({'Actual': Y_test_r2l, 'Predicted': Y_pred_random_r2l})

# %%
metrics.mean_absolute_error(Y_test_r2l,Y_pred_random_r2l)
# Out:
# 0.6809304541124166

# %%
metrics.accuracy_score(Y_test_r2l,Y_pred_random_r2l)
# Out:
# 0.7730231819625278

# %%
metrics.precision_recall_fscore_support(Y_test_r2l,Y_pred_random_r2l, average='weighted')
# Out:
# (0.8246482195734374, 0.7730231819625278, 0.6761243817450092, None)

# %%
#clf_random = RandomForestClassifier(max_depth=20, random_state=0)
clf_random_u2r = RandomForestClassifier(max_depth = 25,random_state=0)
clf_random_u2r.fit(X_train_u2r,Y_train_u2r)
Y_pred_random_u2r=clf_random_u2r.predict(X_test_u2r)
random_df = pd.DataFrame({'Actual': Y_test_u2r, 'Predicted': Y_pred_random_u2r})

# %%
metrics.mean_absolute_error(Y_test_u2r,Y_pred_random_u2r)
# Out:
# 0.026590304765800776

# %%
metrics.accuracy_score(Y_test_u2r,Y_pred_random_u2r)
# Out:
# 0.9933524238085498

# %%
metrics.precision_recall_fscore_support(Y_test_u2r,Y_pred_random_u2r, average='weighted')
# Out:
# (0.9933966231183333, 0.9933524238085498, 0.9902324057654682, None)
