# %%
import pandas as pd
#import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Preprocessing on the Train dataset

# %%
#loading the train dataset
train_df = pd.read_csv("NSL-KDD Dataset/KDDTrain+_20Percent.txt")
train_df
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp  ftp_data    SF        491          0     0
# 1             0           udp     other    SF        146          0     0
# 2             0           tcp   private    S0          0          0     0
# 3             0           tcp      http    SF        232       8153     0
# 4             0           tcp      http    SF        199        420     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 25187         0           tcp      exec  RSTO          0          0     0
# 25188         0           tcp  ftp_data    SF        334          0     0
# 25189         0           tcp   private   REJ          0          0     0
# 25190         0           tcp      nnsp    S0          0          0     0
# 25191         0           tcp    finger    S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# ...

# %% [markdown]
# Assigning numerical value to the labels
#
# 0 for normal
#
# 1 for DOS class attack
#
# 2 for Probe class attack
#
# 3 for R2L class attack
#
# 4 for U2R class attack

# %%
# taking the 'class' columns from the train_df
train_labeldf = train_df['class']
train_labeldf
# Out:
# 0             normal
# 1             normal
# 2            neptune
# 3             normal
# 4             normal
#             ...
# 25187        neptune
# 25188    warezclient
# 25189        neptune
# 25190        neptune
# 25191        neptune
# Name: class, Length: 25192, dtype: object

# %%
#assigning the numerical values                                   
new_train_labeldf=train_labeldf.replace({ 'normal' : 0, 'apache2': 1,'back':1, 'land': 1, 'neptune': 1, 
                                         'mailbomb': 1, 'pod': 1, 'processtable': 1, 'smurf': 1, 
                                         'teardrop': 1,'udpstorm': 1, 'worm': 1,'ipsweep' : 2,
                                         'mscan' : 2, 'nmap' : 2, 'portsweep' : 2,'satan' : 2,
                                         'saint' : 2, 'ftp_write': 3,'guess_passwd': 3,'imap': 3,
                                         'multihop': 3,'phf': 3,'spy': 3,'warezclient': 3, 'warezmaster': 3,
                            'sendmail': 3,'named': 3,'snmpgetattack': 3,'snmpguess': 3, 'xlock': 3,
                            'xsnoop': 3,'httptunnel': 3,'buffer_overflow': 4,'loadmodule': 4,'perl': 4,
                            'rootkit': 4,'ps': 4,'sqlattack': 4,'xterm': 4})
new_train_labeldf
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 25187    1
# 25188    3
# 25189    1
# 25190    1
# 25191    1
# Name: class, Length: 25192, dtype: int64

# %%
#putting the labelled class values back to orignal dataframe (train dataframe)
train_df['class'] = new_train_labeldf
train_df
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp  ftp_data    SF        491          0     0
# 1             0           udp     other    SF        146          0     0
# 2             0           tcp   private    S0          0          0     0
# 3             0           tcp      http    SF        232       8153     0
# 4             0           tcp      http    SF        199        420     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 25187         0           tcp      exec  RSTO          0          0     0
# 25188         0           tcp  ftp_data    SF        334          0     0
# 25189         0           tcp   private   REJ          0          0     0
# 25190         0           tcp      nnsp    S0          0          0     0
# 25191         0           tcp    finger    S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
#converting the categorical values into numerical values - protocol_type, service and flag 

train_df.protocol_type = le.fit_transform(train_df.protocol_type)
train_df.service = le.fit_transform(train_df.service)
train_df.flag = le.fit_transform(train_df.flag)

train_df
# Out:
#        duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0             0              1       19     9        491          0     0
# 1             0              2       41     9        146          0     0
# 2             0              1       46     5          0          0     0
# 3             0              1       22     9        232       8153     0
# 4             0              1       22     9        199        420     0
# ...         ...            ...      ...   ...        ...        ...   ...
# 25187         0              1       16     2          0          0     0
# 25188         0              1       19     9        334          0     0
# 25189         0              1       46     1          0          0     0
# 25190         0              1       38     5          0          0     0
# 25191         0              1       17     5          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# ...

# %%
train_df.describe()
# Out:
#            duration  protocol_type       service          flag     src_bytes  \
# count  25192.000000   25192.000000  25192.000000  25192.000000  2.519200e+04
# mean     305.054104       1.053827     29.039139      6.982455  2.433063e+04
# std     2686.555640       0.426998     15.555601      2.679322  2.410805e+06
# min        0.000000       0.000000      0.000000      0.000000  0.000000e+00
# 25%        0.000000       1.000000     19.000000      5.000000  0.000000e+00
# 50%        0.000000       1.000000     22.000000      9.000000  4.400000e+01
# 75%        0.000000       1.000000     46.000000      9.000000  2.790000e+02
# max    42862.000000       2.000000     65.000000     10.000000  3.817091e+08
#
#           dst_bytes          land  wrong_fragment       urgent           hot  \
# count  2.519200e+04  25192.000000    25192.000000  25192.00000  25192.000000
# mean   3.491847e+03      0.000079        0.023738      0.00004      0.198039
# ...

# %%
train_df.protocol_type = train_df.protocol_type.astype('category')
train_df.service = train_df.service.astype('category')
train_df.flag = train_df.flag.astype('category')

train_df.describe(include='all')
# Out:
#             duration  protocol_type  service     flag     src_bytes  \
# count   25192.000000        25192.0  25192.0  25192.0  2.519200e+04
# unique           NaN            3.0     66.0     11.0           NaN
# top              NaN            1.0     22.0      9.0           NaN
# freq             NaN        20526.0   8003.0  14973.0           NaN
# mean      305.054104            NaN      NaN      NaN  2.433063e+04
# std      2686.555640            NaN      NaN      NaN  2.410805e+06
# min         0.000000            NaN      NaN      NaN  0.000000e+00
# 25%         0.000000            NaN      NaN      NaN  0.000000e+00
# 50%         0.000000            NaN      NaN      NaN  4.400000e+01
# 75%         0.000000            NaN      NaN      NaN  2.790000e+02
# max     42862.000000            NaN      NaN      NaN  3.817091e+08
#
#            dst_bytes          land  wrong_fragment       urgent           hot  \
# ...

# %%
X_train = train_df[['duration','protocol_type','service','flag','src_bytes','dst_bytes','land','wrong_fragment','urgent',
        'hot','num_failed_logins','logged_in','num_compromised','root_shell','su_attempted','num_root',
        'num_file_creations','num_shells','num_access_files','num_outbound_cmds','is_host_login','is_guest_login',
        'count','srv_count','serror_rate','srv_serror_rate','rerror_rate','srv_rerror_rate','same_srv_rate','diff_srv_rate',
        'srv_diff_host_rate','dst_host_count','dst_host_srv_count','dst_host_same_srv_rate','dst_host_diff_srv_rate',
        'dst_host_same_src_port_rate','dst_host_srv_diff_host_rate','dst_host_serror_rate','dst_host_srv_serror_rate',
        'dst_host_rerror_rate','dst_host_srv_rerror_rate']]

Y_train = train_df['class']

# %%
X_train
# Out:
#        duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 0             0             1      19    9        491          0     0
# 1             0             2      41    9        146          0     0
# 2             0             1      46    5          0          0     0
# 3             0             1      22    9        232       8153     0
# 4             0             1      22    9        199        420     0
# ...         ...           ...     ...  ...        ...        ...   ...
# 25187         0             1      16    2          0          0     0
# 25188         0             1      19    9        334          0     0
# 25189         0             1      46    1          0          0     0
# 25190         0             1      38    5          0          0     0
# 25191         0             1      17    5          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# ...

# %%
Y_train
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 25187    1
# 25188    3
# 25189    1
# 25190    1
# 25191    1
# Name: class, Length: 25192, dtype: int64

# %% [markdown]
# ### Preprocessing on the Test dataset

# %%
#loading test dataset
test_df = pd.read_csv("KDDTest+.txt")
test_df
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   private   REJ          0          0     0
# 1             0           tcp   private   REJ          0          0     0
# 2             2           tcp  ftp_data    SF      12983          0     0
# 3             0          icmp     eco_i    SF         20          0     0
# 4             1           tcp    telnet  RSTO          0         15     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 22539         0           tcp      smtp    SF        794        333     0
# 22540         0           tcp      http    SF        317        938     0
# 22541         0           tcp      http    SF      54540       8314     0
# 22542         0           udp  domain_u    SF         42         42     0
# 22543         0           tcp    sunrpc   REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# ...

# %%
# taking the 'class' columns from the test_df
test_labeldf = test_df['class']
test_labeldf
# Out:
# 0        neptune
# 1        neptune
# 2         normal
# 3          saint
# 4          mscan
#           ...
# 22539     normal
# 22540     normal
# 22541       back
# 22542     normal
# 22543      mscan
# Name: class, Length: 22544, dtype: object

# %%
#assigning the numerical values  
new_test_labeldf = test_labeldf.replace ({ 'normal' : 0, 'apache2': 1, 'back':1, 'land': 1, 'neptune': 1, 'mailbomb': 1, 'pod': 1, 'processtable': 1, 'smurf': 1, 'teardrop': 1, 'udpstorm': 1, 'worm': 1,
                                         'ipsweep' : 2, 'mscan' : 2, 'nmap' : 2,'portsweep' : 2,'satan' : 2,'saint' : 2,
                           'ftp_write': 3,'guess_passwd': 3,'imap': 3,'multihop': 3,'phf': 3,'spy': 3,'warezclient': 3,'warezmaster': 3,'sendmail': 3,'named': 3,'snmpgetattack': 3,'snmpguess': 3,'xlock': 3,'xsnoop': 3,'httptunnel': 3,
                           'buffer_overflow': 4,'loadmodule': 4,'perl': 4,'rootkit': 4,'ps': 4,'sqlattack': 4,'xterm': 4})

new_test_labeldf
# Out:
# 0        1
# 1        1
# 2        0
# 3        2
# 4        2
#         ..
# 22539    0
# 22540    0
# 22541    1
# 22542    0
# 22543    2
# Name: class, Length: 22544, dtype: int64

# %%
# putting the labelled class values back to orignal dataframe (test dataframe)
test_df['class'] = new_test_labeldf
test_df
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   private   REJ          0          0     0
# 1             0           tcp   private   REJ          0          0     0
# 2             2           tcp  ftp_data    SF      12983          0     0
# 3             0          icmp     eco_i    SF         20          0     0
# 4             1           tcp    telnet  RSTO          0         15     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 22539         0           tcp      smtp    SF        794        333     0
# 22540         0           tcp      http    SF        317        938     0
# 22541         0           tcp      http    SF      54540       8314     0
# 22542         0           udp  domain_u    SF         42         42     0
# 22543         0           tcp    sunrpc   REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# ...

# %%
#converting the categorical values into numerical values - protocol_type, service and flag 

test_df.protocol_type = le.fit_transform(test_df.protocol_type)
test_df.service = le.fit_transform(test_df.service)
test_df.flag = le.fit_transform(test_df.flag)

test_df
# Out:
#        duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0             0              1       45     1          0          0     0
# 1             0              1       45     1          0          0     0
# 2             2              1       19     9      12983          0     0
# 3             0              0       13     9         20          0     0
# 4             1              1       55     2          0         15     0
# ...         ...            ...      ...   ...        ...        ...   ...
# 22539         0              1       49     9        794        333     0
# 22540         0              1       22     9        317        938     0
# 22541         0              1       22     9      54540       8314     0
# 22542         0              2       11     9         42         42     0
# 22543         0              1       52     1          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# ...

# %%
test_df.describe()
# Out:
#            duration  protocol_type       service          flag     src_bytes  \
# count  22544.000000   22544.000000  22544.000000  22544.000000  2.254400e+04
# mean     218.859076       1.069996     31.629879      6.874157  1.039545e+04
# std     1407.176612       0.397032     14.315780      3.210074  4.727864e+05
# min        0.000000       0.000000      0.000000      0.000000  0.000000e+00
# 25%        0.000000       1.000000     22.000000      5.000000  0.000000e+00
# 50%        0.000000       1.000000     22.000000      9.000000  5.400000e+01
# 75%        0.000000       1.000000     45.000000      9.000000  2.870000e+02
# max    57715.000000       2.000000     63.000000     10.000000  6.282565e+07
#
#           dst_bytes          land  wrong_fragment        urgent           hot  \
# count  2.254400e+04  22544.000000    22544.000000  22544.000000  22544.000000
# mean   2.056019e+03      0.000311        0.008428      0.000710      0.105394
# ...

# %%
test_df.protocol_type = test_df.protocol_type.astype('category')
test_df.service =test_df.service.astype('category')
test_df.flag = test_df.flag.astype('category')

test_df.describe(include='all')
# Out:
#             duration  protocol_type  service     flag     src_bytes  \
# count   22544.000000        22544.0  22544.0  22544.0  2.254400e+04
# unique           NaN            3.0     64.0     11.0           NaN
# top              NaN            1.0     22.0      9.0           NaN
# freq             NaN        18880.0   7853.0  14875.0           NaN
# mean      218.859076            NaN      NaN      NaN  1.039545e+04
# std      1407.176612            NaN      NaN      NaN  4.727864e+05
# min         0.000000            NaN      NaN      NaN  0.000000e+00
# 25%         0.000000            NaN      NaN      NaN  0.000000e+00
# 50%         0.000000            NaN      NaN      NaN  5.400000e+01
# 75%         0.000000            NaN      NaN      NaN  2.870000e+02
# max     57715.000000            NaN      NaN      NaN  6.282565e+07
#
#            dst_bytes          land  wrong_fragment        urgent  \
# count   2.254400e+04  22544.000000    22544.000000  22544.000000
# ...

# %%
X_test = test_df[['duration','protocol_type','service','flag','src_bytes','dst_bytes','land','wrong_fragment','urgent',
        'hot','num_failed_logins','logged_in','num_compromised','root_shell','su_attempted','num_root',
        'num_file_creations','num_shells','num_access_files','num_outbound_cmds','is_host_login','is_guest_login',
        'count','srv_count','serror_rate','srv_serror_rate','rerror_rate','srv_rerror_rate','same_srv_rate','diff_srv_rate',
        'srv_diff_host_rate','dst_host_count','dst_host_srv_count','dst_host_same_srv_rate','dst_host_diff_srv_rate',
        'dst_host_same_src_port_rate','dst_host_srv_diff_host_rate','dst_host_serror_rate','dst_host_srv_serror_rate',
        'dst_host_rerror_rate','dst_host_srv_rerror_rate']]

Y_test = test_df['class']

# %%
X_test
# Out:
#        duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 0             0             1      45    1          0          0     0
# 1             0             1      45    1          0          0     0
# 2             2             1      19    9      12983          0     0
# 3             0             0      13    9         20          0     0
# 4             1             1      55    2          0         15     0
# ...         ...           ...     ...  ...        ...        ...   ...
# 22539         0             1      49    9        794        333     0
# 22540         0             1      22    9        317        938     0
# 22541         0             1      22    9      54540       8314     0
# 22542         0             2      11    9         42         42     0
# 22543         0             1      52    1          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# ...

# %%
Y_test
# Out:
# 0        1
# 1        1
# 2        0
# 3        2
# 4        2
#         ..
# 22539    0
# 22540    0
# 22541    1
# 22542    0
# 22543    2
# Name: class, Length: 22544, dtype: int64

# %%
print('Train set:', X_train.shape,  Y_train.shape)
print ('Test set:', X_test.shape,  Y_test.shape)
# Out:
# Train set: (25192, 41) (25192,)
# Test set: (22544, 41) (22544,)

# %% [markdown]
# ## SVM

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn import metrics

# %%
rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train, Y_train)
#poly = svm.SVC(kernel='poly', degree=3, C=1).fit(X_train, Y_train)

# %%
rbf_pred = rbf.predict(X_test)
#poly_pred = poly.predict(X_test)

# %%
rbf_accuracy = accuracy_score(Y_test, rbf_pred)
rbf_f1 = f1_score(Y_test, rbf_pred, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
# Out:
# Accuracy (RBF Kernel):  44.09
# F1 (RBF Kernel):  28.01

# %%
metrics.accuracy_score(Y_test,rbf_pred)
# Out:
# 0.44087118523775726

# %%
metrics.precision_recall_fscore_support(Y_test,rbf_pred, average='weighted')
# Out:
# (0.6257463387842552, 0.44087118523775726, 0.280135248921157, None)

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
from sklearn import metrics

# %%
clf_Tree = tree.DecisionTreeClassifier()

# %%
clf_Tree.fit(X_train_df,Y_train_df)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred_Tree=clf_Tree.predict(X_test_df)

# %%
Y_pred_Tree
# Out:
# array([1, 1, 0, ..., 1, 0, 2], dtype=int64)

# %%
tree_df = pd.DataFrame({'Actual': Y_test_df, 'Predicted': Y_pred_Tree})

# %%
tree_df.shape
# Out:
# (22544, 2)

# %%
tree_df.head(30)
# Out:
#     Actual  Predicted
# 0        1          1
# 1        1          1
# 2        0          0
# 3        2          2
# 4        2          0
# 5        0          0
# 6        0          0
# 7        3          0
# 8        0          0
# 9        3          0
# 10       2          2
# 11       0          0
# 12       1          1
# 13       1          1
# 14       0          0
# 15       0          0
# 16       0          0
# 17       0          0
# 18       0          0
# 19       1          1
# 20       1          1
# 21       2          1
# 22       0          0
# 23       0          0
# 24       1          1
# 25       1          1
# 26       0          0
# 27       0          0
# 28       1          1
# 29       0          0

# %% [markdown]
# #### Decision Tree Classifier - Performance Metrics

# %%
metrics.mean_absolute_error(Y_test_df,Y_pred_Tree)
# Out:
# 0.50638750887154

# %%
metrics.accuracy_score(Y_test_df,Y_pred_Tree)
# Out:
# 0.7590933286018453

# %%
metrics.precision_recall_fscore_support(Y_test_df,Y_pred_Tree, average='weighted')
# Out:
# (0.7892162819494215, 0.7590933286018453, 0.7164211149617815, None)

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#clf_random = RandomForestClassifier(max_depth=20, random_state=0)
clf_random = RandomForestClassifier(max_depth = 5)

# %%
clf_random.fit(X_train_df,Y_train_df)
# Out:
# RandomForestClassifier(max_depth=5)

# %%
Y_pred_random=clf_random.predict(X_test_df)

# %%
Y_pred_random
# Out:
# array([1, 1, 0, ..., 1, 0, 1], dtype=int64)

# %%
random_df = pd.DataFrame({'Actual': Y_test_df, 'Predicted': Y_pred_random})

# %%
random_df.shape
# Out:
# (22544, 2)

# %%
random_df.head(30)
# Out:
#     Actual  Predicted
# 0        1          1
# 1        1          1
# 2        0          0
# 3        2          2
# 4        2          0
# 5        0          0
# 6        0          0
# 7        3          0
# 8        0          0
# 9        3          0
# 10       2          0
# 11       0          0
# 12       1          1
# 13       1          1
# 14       0          0
# 15       0          0
# 16       0          0
# 17       0          0
# 18       0          0
# 19       1          1
# 20       1          1
# 21       2          1
# 22       0          0
# 23       0          0
# 24       1          1
# 25       1          1
# 26       0          0
# 27       0          0
# 28       1          1
# 29       0          0

# %% [markdown]
# #### Random Forest Classifier - Performance Metrics

# %%
metrics.mean_absolute_error(Y_test_df,Y_pred_random)
# Out:
# 0.5750975869410929

# %%
metrics.accuracy_score(Y_test_df,Y_pred_random)
# Out:
# 0.7279542228530873

# %%
metrics.precision_recall_fscore_support(Y_test_df,Y_pred_random,average='weighted')
# Out:
# (0.6765716112556106, 0.7279542228530873, 0.6789642031390759, None)
