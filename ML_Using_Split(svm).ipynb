# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings


from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
warnings.filterwarnings('ignore')

le = preprocessing.LabelEncoder()

# %%
#loading the train and test dataset
train_df = pd.read_csv("NSL-KDD Dataset/KDDTrain+_20Percent.txt")


test_df = pd.read_csv("KDDTest+.txt")
train_df
test_df
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   private   REJ          0          0     0
# 1             0           tcp   private   REJ          0          0     0
# 2             2           tcp  ftp_data    SF      12983          0     0
# 3             0          icmp     eco_i    SF         20          0     0
# 4             1           tcp    telnet  RSTO          0         15     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 22539         0           tcp      smtp    SF        794        333     0
# 22540         0           tcp      http    SF        317        938     0
# 22541         0           tcp      http    SF      54540       8314     0
# 22542         0           udp  domain_u    SF         42         42     0
# 22543         0           tcp    sunrpc   REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# ...

# %%
#Drop severity score column



#assigning the numerical values to class  

label_train_df=train_df['class']


frame_train=label_train_df.replace({ 'normal' : 0, 'apache2': 1,'back':1, 'land': 1, 'neptune': 1, 
                                         'mailbomb': 1, 'pod': 1, 'processtable': 1, 'smurf': 1, 
                                         'teardrop': 1,'udpstorm': 1, 'worm': 1,'ipsweep' : 2,
                                         'mscan' : 2, 'nmap' : 2, 'portsweep' : 2,'satan' : 2,
                                         'saint' : 2, 'ftp_write': 3,'guess_passwd': 3,'imap': 3,
                                         'multihop': 3,'phf': 3,'spy': 3,'warezclient': 3, 'warezmaster': 3,
                            'sendmail': 3,'named': 3,'snmpgetattack': 3,'snmpguess': 3, 'xlock': 3,
                            'xsnoop': 3,'httptunnel': 3,'buffer_overflow': 4,'loadmodule': 4,'perl': 4,
                            'rootkit': 4,'ps': 4,'sqlattack': 4,'xterm': 4})



# train_df

frame_train

#frame_test
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 25187    1
# 25188    3
# 25189    1
# 25190    1
# 25191    1
# Name: class, Length: 25192, dtype: int64

# %%
#uptile here we loaded data, and we droped column-severity score
#assigned label for column class
#we mapped each class as key-value pair
# train_df = train_df.drop(['severity_score'],axis=1)
label_test_df=test_df['class']
frame_test=label_test_df.replace({ 'normal' : 0, 'apache2': 1,'back':1, 'land': 1, 'neptune': 1, 
                                         'mailbomb': 1, 'pod': 1, 'processtable': 1, 'smurf': 1, 
                                         'teardrop': 1,'udpstorm': 1, 'worm': 1,'ipsweep' : 2,
                                         'mscan' : 2, 'nmap' : 2, 'portsweep' : 2,'satan' : 2,
                                         'saint' : 2, 'ftp_write': 3,'guess_passwd': 3,'imap': 3,
                                         'multihop': 3,'phf': 3,'spy': 3,'warezclient': 3, 'warezmaster': 3,
                            'sendmail': 3,'named': 3,'snmpgetattack': 3,'snmpguess': 3, 'xlock': 3,
                            'xsnoop': 3,'httptunnel': 3,'buffer_overflow': 4,'loadmodule': 4,'perl': 4,
                            'rootkit': 4,'ps': 4,'sqlattack': 4,'xterm': 4})

frame_test
# Out:
# 0        1
# 1        1
# 2        0
# 3        2
# 4        2
#         ..
# 22539    0
# 22540    0
# 22541    1
# 22542    0
# 22543    2
# Name: class, Length: 22544, dtype: int64

# %%
train_df['class'] = frame_train
train_df
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp  ftp_data    SF        491          0     0
# 1             0           udp     other    SF        146          0     0
# 2             0           tcp   private    S0          0          0     0
# 3             0           tcp      http    SF        232       8153     0
# 4             0           tcp      http    SF        199        420     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 25187         0           tcp      exec  RSTO          0          0     0
# 25188         0           tcp  ftp_data    SF        334          0     0
# 25189         0           tcp   private   REJ          0          0     0
# 25190         0           tcp      nnsp    S0          0          0     0
# 25191         0           tcp    finger    S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# ...

# %%
test_df['class'] = frame_test
test_df
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   private   REJ          0          0     0
# 1             0           tcp   private   REJ          0          0     0
# 2             2           tcp  ftp_data    SF      12983          0     0
# 3             0          icmp     eco_i    SF         20          0     0
# 4             1           tcp    telnet  RSTO          0         15     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 22539         0           tcp      smtp    SF        794        333     0
# 22540         0           tcp      http    SF        317        938     0
# 22541         0           tcp      http    SF      54540       8314     0
# 22542         0           udp  domain_u    SF         42         42     0
# 22543         0           tcp    sunrpc   REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# ...

# %%
train_df = train_df.drop(['severity_score'], axis = 1)
train_df
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp  ftp_data    SF        491          0     0
# 1             0           udp     other    SF        146          0     0
# 2             0           tcp   private    S0          0          0     0
# 3             0           tcp      http    SF        232       8153     0
# 4             0           tcp      http    SF        199        420     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 25187         0           tcp      exec  RSTO          0          0     0
# 25188         0           tcp  ftp_data    SF        334          0     0
# 25189         0           tcp   private   REJ          0          0     0
# 25190         0           tcp      nnsp    S0          0          0     0
# 25191         0           tcp    finger    S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %%
test_df = test_df.drop(['severity_score'], axis = 1)
test_df
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   private   REJ          0          0     0
# 1             0           tcp   private   REJ          0          0     0
# 2             2           tcp  ftp_data    SF      12983          0     0
# 3             0          icmp     eco_i    SF         20          0     0
# 4             1           tcp    telnet  RSTO          0         15     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 22539         0           tcp      smtp    SF        794        333     0
# 22540         0           tcp      http    SF        317        938     0
# 22541         0           tcp      http    SF      54540       8314     0
# 22542         0           udp  domain_u    SF         42         42     0
# 22543         0           tcp    sunrpc   REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %%
#converting the categorical values into numerical values - protocol_type, service and flag 
# for train
train_df.protocol_type = le.fit_transform(train_df.protocol_type)
train_df.service = le.fit_transform(train_df.service)
train_df.flag = le.fit_transform(train_df.flag)

train_df.protocol_type = train_df.protocol_type.astype('category')
train_df.service = train_df.service.astype('category')
train_df.flag = train_df.flag.astype('category')

train_df.describe(include='all')
# Out:
#             duration  protocol_type  service     flag     src_bytes  \
# count   25192.000000        25192.0  25192.0  25192.0  2.519200e+04
# unique           NaN            3.0     66.0     11.0           NaN
# top              NaN            1.0     22.0      9.0           NaN
# freq             NaN        20526.0   8003.0  14973.0           NaN
# mean      305.054104            NaN      NaN      NaN  2.433063e+04
# std      2686.555640            NaN      NaN      NaN  2.410805e+06
# min         0.000000            NaN      NaN      NaN  0.000000e+00
# 25%         0.000000            NaN      NaN      NaN  0.000000e+00
# 50%         0.000000            NaN      NaN      NaN  4.400000e+01
# 75%         0.000000            NaN      NaN      NaN  2.790000e+02
# max     42862.000000            NaN      NaN      NaN  3.817091e+08
#
#            dst_bytes          land  wrong_fragment       urgent           hot  \
# ...

# %%
train_df
# Out:
#        duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 0             0             1      19    9        491          0     0
# 1             0             2      41    9        146          0     0
# 2             0             1      46    5          0          0     0
# 3             0             1      22    9        232       8153     0
# 4             0             1      22    9        199        420     0
# ...         ...           ...     ...  ...        ...        ...   ...
# 25187         0             1      16    2          0          0     0
# 25188         0             1      19    9        334          0     0
# 25189         0             1      46    1          0          0     0
# 25190         0             1      38    5          0          0     0
# 25191         0             1      17    5          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %%
#converting the categorical values into numerical values - protocol_type, service and flag 
# for test
test_df.protocol_type = le.fit_transform(test_df.protocol_type)
test_df.service = le.fit_transform(test_df.service)
test_df.flag = le.fit_transform(test_df.flag)

test_df.protocol_type = test_df.protocol_type.astype('category')
test_df.service = test_df.service.astype('category')
test_df.flag = test_df.flag.astype('category')

test_df.describe(include='all')
# Out:
#             duration  protocol_type  service     flag     src_bytes  \
# count   22544.000000        22544.0  22544.0  22544.0  2.254400e+04
# unique           NaN            3.0     64.0     11.0           NaN
# top              NaN            1.0     22.0      9.0           NaN
# freq             NaN        18880.0   7853.0  14875.0           NaN
# mean      218.859076            NaN      NaN      NaN  1.039545e+04
# std      1407.176612            NaN      NaN      NaN  4.727864e+05
# min         0.000000            NaN      NaN      NaN  0.000000e+00
# 25%         0.000000            NaN      NaN      NaN  0.000000e+00
# 50%         0.000000            NaN      NaN      NaN  5.400000e+01
# 75%         0.000000            NaN      NaN      NaN  2.870000e+02
# max     57715.000000            NaN      NaN      NaN  6.282565e+07
#
#            dst_bytes          land  wrong_fragment        urgent  \
# count   2.254400e+04  22544.000000    22544.000000  22544.000000
# ...

# %%
test_df
# Out:
#        duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 0             0             1      45    1          0          0     0
# 1             0             1      45    1          0          0     0
# 2             2             1      19    9      12983          0     0
# 3             0             0      13    9         20          0     0
# 4             1             1      55    2          0         15     0
# ...         ...           ...     ...  ...        ...        ...   ...
# 22539         0             1      49    9        794        333     0
# 22540         0             1      22    9        317        938     0
# 22541         0             1      22    9      54540       8314     0
# 22542         0             2      11    9         42         42     0
# 22543         0             1      52    1          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %%
# Rename every attack label: 0=normal, 1=DoS, 2=Probe, 3=R2L and 4=U2R.
#for-train
to_keep_dos=[0,1]
to_keep_probe=[0,2]
to_keep_r2l=[0,3]
to_keep_u2r=[0,4]
dos_df=train_df[train_df['class'].isin(to_keep_dos)];
probe_df=train_df[train_df['class'].isin(to_keep_probe)];
r2l_df=train_df[train_df['class'].isin(to_keep_r2l)];
u2r_df=train_df[train_df['class'].isin(to_keep_u2r)];

dos_df
# Out:
#        duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 0             0             1      19    9        491          0     0
# 1             0             2      41    9        146          0     0
# 2             0             1      46    5          0          0     0
# 3             0             1      22    9        232       8153     0
# 4             0             1      22    9        199        420     0
# ...         ...           ...     ...  ...        ...        ...   ...
# 25186         0             1      22    6        339      14600     0
# 25187         0             1      16    2          0          0     0
# 25189         0             1      46    1          0          0     0
# 25190         0             1      38    5          0          0     0
# 25191         0             1      17    5          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %%
# Rename every attack label: 0=normal, 1=DoS, 2=Probe, 3=R2L and 4=U2R.
#for-test

dos_df_test=test_df[test_df['class'].isin(to_keep_dos)];
probe_df_test=test_df[test_df['class'].isin(to_keep_probe)];
r2l_df_test=test_df[test_df['class'].isin(to_keep_r2l)];
u2r_df_test=test_df[test_df['class'].isin(to_keep_u2r)];

u2r_df_test
# Out:
#        duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 2             2             1      19    9      12983          0     0
# 5             0             1      22    9        267      14515     0
# 6             0             1      49    9       1022        387     0
# 8             0             1      22    9        327        467     0
# 11            0             1      49    9        616        330     0
# ...         ...           ...     ...  ...        ...        ...   ...
# 22533         0             1      22    9        274       1623     0
# 22535         0             1      22    9        280       6087     0
# 22539         0             1      49    9        794        333     0
# 22540         0             1      22    9        317        938     0
# 22542         0             2      11    9         42         42     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %%
# Split dataframes into X & Y
# assign X as a dataframe of feautures and Y as a series of outcome variables
X_train_dos = dos_df.drop('class',1)
Y_train_dos = dos_df['class']
X_train_probe = probe_df.drop('class',1)
Y_train_probe = probe_df['class']
X_train_r2l = r2l_df.drop('class',1)
Y_train_r2l = r2l_df['class']
X_train_u2r = u2r_df.drop('class',1)
Y_train_u2r = u2r_df['class']

X_train_dos
# Out:
#        duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 0             0             1      19    9        491          0     0
# 1             0             2      41    9        146          0     0
# 2             0             1      46    5          0          0     0
# 3             0             1      22    9        232       8153     0
# 4             0             1      22    9        199        420     0
# ...         ...           ...     ...  ...        ...        ...   ...
# 25186         0             1      22    6        339      14600     0
# 25187         0             1      16    2          0          0     0
# 25189         0             1      46    1          0          0     0
# 25190         0             1      38    5          0          0     0
# 25191         0             1      17    5          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# ...

# %%
# Split dataframes into X & Y
# assign X as a dataframe of feautures and Y as a series of outcome variables
X_test_dos = dos_df_test.drop('class',1)
Y_test_dos = dos_df_test['class']
X_test_probe = probe_df_test.drop('class',1)
Y_test_probe = probe_df_test['class']
X_test_r2l = r2l_df_test.drop('class',1)
Y_test_r2l = r2l_df_test['class']
X_test_u2r = u2r_df_test.drop('class',1)
Y_test_u2r = u2r_df_test['class']

X_test_dos
# Out:
#        duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 0             0             1      45    1          0          0     0
# 1             0             1      45    1          0          0     0
# 2             2             1      19    9      12983          0     0
# 5             0             1      22    9        267      14515     0
# 6             0             1      49    9       1022        387     0
# ...         ...           ...     ...  ...        ...        ...   ...
# 22538         0             0      14    9       1032          0     0
# 22539         0             1      49    9        794        333     0
# 22540         0             1      22    9        317        938     0
# 22541         0             1      22    9      54540       8314     0
# 22542         0             2      11    9         42         42     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# ...

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn import metrics

# %%
rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train_dos, Y_train_dos)
#poly = svm.SVC(kernel='poly', degree=3, C=1).fit(X_train, Y_train)

# %%
rbf_pred_dos = rbf.predict(X_test_dos)
#poly_pred = poly.predict(X_test)

# %%
rbf_accuracy = accuracy_score(Y_test_dos, rbf_pred_dos)
rbf_f1 = f1_score(Y_test_dos, rbf_pred_dos, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
# Out:
# Accuracy (RBF Kernel):  56.74
# F1 (RBF Kernel):  41.28

# %%
metrics.accuracy_score(Y_test_dos,rbf_pred_dos)
# Out:
# 0.5674101683070293

# %%
metrics.precision_recall_fscore_support(Y_test_dos,rbf_pred_dos, average='weighted')
# Out:
# (0.7548935261351049, 0.5674101683070293, 0.412800505488325, None)

# %%
#for probe
rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train_probe, Y_train_probe)
#poly = svm.SVC(kernel='poly', degree=3, C=1).fit(X_train, Y_train)
rbf_pred_probe = rbf.predict(X_test_probe)
#poly_pred = poly.predict(X_test)
rbf_accuracy = accuracy_score(Y_test_probe, rbf_pred_probe)
rbf_f1 = f1_score(Y_test_probe, rbf_pred_probe, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
# Out:
# Accuracy (RBF Kernel):  81.66
# F1 (RBF Kernel):  74.81

# %%
metrics.accuracy_score(Y_test_probe,rbf_pred_probe)
# Out:
# 0.8166007253544345

# %%
metrics.precision_recall_fscore_support(Y_test_probe,rbf_pred_probe, average='weighted')
# Out:
# (0.8507883414809747, 0.8166007253544345, 0.748062164375824, None)

# %%
#for r2l

rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train_r2l, Y_train_r2l)
#poly = svm.SVC(kernel='poly', degree=3, C=1).fit(X_train, Y_train)
rbf_pred_r2l = rbf.predict(X_test_r2l)
#poly_pred = poly.predict(X_test)
rbf_accuracy = accuracy_score(Y_test_r2l, rbf_pred_r2l)
rbf_f1 = f1_score(Y_test_r2l, rbf_pred_r2l, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
# Out:
# Accuracy (RBF Kernel):  77.10
# F1 (RBF Kernel):  67.12

# %%
metrics.accuracy_score(Y_test_r2l,rbf_pred_r2l)
# Out:
# 0.7709590346141633

# %%
metrics.precision_recall_fscore_support(Y_test_r2l,rbf_pred_r2l, average='weighted')
# Out:
# (0.5943778330532026, 0.7709590346141633, 0.6712496691745317, None)

# %%
#for u2r

rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train_u2r, Y_train_u2r)
#poly = svm.SVC(kernel='poly', degree=3, C=1).fit(X_train, Y_train)
rbf_pred_u2r = rbf.predict(X_test_u2r)
#poly_pred = poly.predict(X_test)
rbf_accuracy = accuracy_score(Y_test_u2r, rbf_pred_u2r)
rbf_f1 = f1_score(Y_test_u2r, rbf_pred_u2r, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
# Out:
# Accuracy (RBF Kernel):  99.31
# F1 (RBF Kernel):  98.97

# %%
metrics.accuracy_score(Y_test_u2r,rbf_pred_u2r)
# Out:
# 0.993147883002659

# %%
metrics.precision_recall_fscore_support(Y_test_u2r,rbf_pred_u2r, average='weighted')
# Out:
# (0.9863427175126633, 0.993147883002659, 0.9897336027337289, None)
